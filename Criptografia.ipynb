# %% [markdown]
# <a href="https://colab.research.google.com/github/juliagermanosilva-pixel/Criptografia/blob/main/Criptografia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#brute force - trabalha a tentativa e erro via combinações
import itertools #biblioteca que faz combinações
import string #preciso saber como o pc pensa em um texto
import time
#computador falar para mim quanto tempo leva para descobrir uma senha
#passo1 - alvo - o que o pc tenta adivinhar
def simulacao():
  senha_alvo = input('Digite uma senha')
#passo2 - armazenar tudo que ja foi feito
  #o pc usa uma tabela chamada ascii para salvar caracteres
  caracteres = string.ascii_lowercase + string.digits
  #estamos juntando todas as letras e numeros
  print('tentando descobrir sua senha!')
  tempo_inicio = time.time()
  #time.time() registra o momento que o sistema iniciou
  tentativas = 0
  encontrado = False
#passo3 - tentar descobrir algo
  for comprimento in range (1, len(senha_alvo)+1):
    if encontrado: #if nome_encontrado ------ if var = True
      break
#passo4 - combinado
    for combinacao in itertools.product(caracteres, repeat= comprimento):
      tentativas += 1
      palpite = '---'.join(combinacao)
#passo5 - feedback - mostrar o que está fazendo
    if tentativas % 100000 == 0:
      print(f'tentativa de número {tentativas} testanto o palpite {palpite}')
    if palpite == senha_alvo:
      tempo_fim = time.time()
      duracao = tempo_fim - tempo_inicio
      encontrado = True
#passo6 - finalizar tudo
simulacao()
# Out:
# tentando descobrir sua senha!
